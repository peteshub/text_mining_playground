# %%
from nltk.classify import NaiveBayesClassifier
import sqlite3
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

import utils.data_prep as data_prep

# %%
data_set = data_prep.get_dataset()
data_set.head()
# Out:
#   company  year  page  paragraph_nr  \
# 0    BASF  2016     4            64
# 1    BASF  2016     4            65
# 2    BASF  2016     4            66
# 3    BASF  2016     4            67
# 4    BASF  2016     4            68
#
#                                            paragraph          section  class
# 0  154 Consolidated Financial  Statements  BASF R...  auditors report      3
# 1                                   Auditor’s report  auditors report      3
# 2                                   Auditor’s report  auditors report      3
# 3  We have audited the consolidated financial sta...  auditors report      3
# 4  assurance. Knowledge of the business activitie...  auditors report      3

# %%
sections = (data_set.groupby(['company','year','section','class','page'])['paragraph']
            .apply(lambda x: ' '.join(x))
            .reset_index())
sections.head(20)
# Out:
#    company  year                section  class  page  \
# 0     Adva  2016           auditors fee      2    61
# 1     Adva  2016        auditors report      3    71
# 2     Adva  2016  business combinations      5    25
# 3     Adva  2016  business combinations      5    26
# 4     Adva  2016  business combinations      5    27
# 5     Adva  2016        cash flow notes      6    50
# 6     Adva  2016             cash_equiv      7    28
# 7     Adva  2016                    eps     11    50
# 8     Adva  2016                 equity     12    41
# 9     Adva  2016                 equity     12    42
# 10    Adva  2016  financial instruments     15    54
# 11    Adva  2016  financial instruments     15    55
# 12    Adva  2016  financial instruments     15    56
# 13    Adva  2016  financial instruments     15    57
# 14    Adva  2016  financial instruments     15    58
# 15    Adva  2016  financial instruments     15    59
# 16    Adva  2016  financial instruments     15    60
# 17    Adva  2016  financial_liabilities     16    36
# 18    Adva  2016                general     17     8
# 19    Adva  2016                general     17     9
#
#                                             paragraph
# 0   Supervisory \nBoard Management \nBoard Welcome...
# 1   Supervisory \nBoard Management \nBoard Welcome...
# 2   The final purchase price allocation according ...
# 3   106            ADVA Optical Networking – Annua...
# 4   Supervisory \nBoard Management \nBoard Welcome...
# 5   130            ADVA Optical Networking – Annua...
# 6   108            ADVA Optical Networking – Annua...
# 7   130            ADVA Optical Networking – Annua...
# 8   Supervisory \nBoard Management \nBoard Welcome...
# 9   122            ADVA Optical Networking – Annua...
# 10  134            ADVA Optical Networking – Annua...
# 11  Supervisory \nBoard Management \nBoard Welcome...
# 12  136            ADVA Optical Networking – Annua...
# 13  Supervisory \nBoard Management \nBoard Welcome...
# 14  138            ADVA Optical Networking – Annua...
# 15  Supervisory \nBoard Management \nBoard Welcome...
# 16  140            ADVA Optical Networking – Annua...
# 17  116            ADVA Optical Networking – Annua...
# 18  88            ADVA Optical Networking – Annual...
# 19  ADVA Optical Networking – Annual Report 2016  ...

# %%
all_words = sections.groupby(lambda x: True)['paragraph'].apply(lambda x: ' '.join(x)).tolist()
all_words = nltk.word_tokenize(all_words[0])
words = nltk.FreqDist(w.lower() for w in all_words)
# if w.lower() not in stopwords.words('english')

# %%
word_features = list(words)[:3000]

def document_features(section):
    section_words = set([word.lower() for word in nltk.word_tokenize(section)])
    features = {}
    for word in word_features:
        features[word] = (word.lower() in section_words)
    return features


sections['features'] = sections['paragraph'].apply(document_features)
sections.head()
# Out:
#   company  year                section  class  page  \
# 0    Adva  2016           auditors fee      2    61
# 1    Adva  2016        auditors report      3    71
# 2    Adva  2016  business combinations      5    25
# 3    Adva  2016  business combinations      5    26
# 4    Adva  2016  business combinations      5    27
#
#                                            paragraph  \
# 0  Supervisory \nBoard Management \nBoard Welcome...
# 1  Supervisory \nBoard Management \nBoard Welcome...
# 2  The final purchase price allocation according ...
# 3  106            ADVA Optical Networking – Annua...
# 4  Supervisory \nBoard Management \nBoard Welcome...
#
#                                             features
# 0  {'supervisory': True, 'board': True, 'manageme...
# 1  {'supervisory': True, 'board': True, 'manageme...
# 2  {'supervisory': True, 'board': True, 'manageme...
# 3  {'supervisory': False, 'board': False, 'manage...
# 4  {'supervisory': True, 'board': True, 'manageme...

# %%
feature_set = list(zip(sections['features'].values,sections['class'].values))
len(feature_set)
train_set, test_set = feature_set[:2000], feature_set[2000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.627731092437

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#                      fee = True               19 : 17     =    182.0 : 1.0
#                   berlin = True               19 : 17     =    182.0 : 1.0
#                       61 = True               19 : 17     =    182.0 : 1.0
#                      607 = True               19 : 17     =    182.0 : 1.0
#                workforce = True               19 : 17     =    182.0 : 1.0
#                   behalf = True               19 : 17     =    182.0 : 1.0
#                      317 = True                3 : 17     =    134.0 : 1.0
#                     fees = True                2 : 15     =    121.0 : 1.0
#                        , = False              37 : 17     =    118.0 : 1.0
#                     days = True               47 : 17     =    110.0 : 1.0
#                  network = True               19 : 17     =    109.2 : 1.0
#                subsidies = True               19 : 15     =    103.0 : 1.0
#               government = True               19 : 15     =    103.0 : 1.0
#                      hgb = True               19 : 15     =    103.0 : 1.0
#             contribution = True               19 : 15     =    103.0 : 1.0
#                    state = True               19 : 15     =    103.0 : 1.0
#               subscribed = True               37 : 17     =     97.7 : 1.0
#                   leases = True               24 : 33     =     96.2 : 1.0
#                    lease = True               24 : 33     =     96.2 : 1.0
#                   lessor = True               25 : 15     =     96.1 : 1.0
#                 asserted = True               27 : 17     =     93.8 : 1.0
#                four-year = True               44 : 17     =     93.6 : 1.0
#                machinery = True               34 : 15     =     85.4 : 1.0
#                        . = False              35 : 17     =     84.6 : 1.0
#                 goodwill = True               21 : 33     =     83.8 : 1.0
#             construction = True               34 : 15     =     82.1 : 1.0
#                buildings = True               34 : 33     =     81.2 : 1.0
#                     give = True               41 : 33     =     81.0 : 1.0
#                 progress = True               22 : 15     =     80.6 : 1.0
#                temporary = True                8 : 15     =     79.2 : 1.0
